# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from PIL import Image
import matplotlib.pyplot as plt
from glob import glob
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
pd.read_csv("./data/NICE평가정보/BUSAN_DIVE_STAT_202203.csv",encoding='EUC-KR')
# Out:
#       B_DATE META_ADD  GENDER  AGE  AVG_INCOME  MED_INCOME  AVG_INCOMEX  \
# 0     202203       전국       0    0        3717        3100         3070
# 1     202203       전국       0   10        2097        2000         2088
# 2     202203       전국       0   20        2674        2300         2466
# 3     202203       전국       0   30        3794        3200         3021
# 4     202203       전국       0   40        4534        3700         3541
# ...      ...      ...     ...  ...         ...         ...          ...
# 2128  202203  충청북도충주시       2   40        3692        3200         3082
# 2129  202203  충청북도충주시       2   50        3623        3200         3045
# 2130  202203  충청북도충주시       2   60        2955        2600         2591
# 2131  202203  충청북도충주시       2   70        2354        2100         2197
# 2132  202203  충청북도충주시       2   80        1566        1500         1484
#
#       IN_DIST_RO  IN_SH  IN_MAX  ...  SUM_CHECK_1   SUM_ABRO_1  AVG_CRED_1  \
# ...

# %%
pd.read_excel('./data/롯데멤버스/005_ltmb_lime_table.xlsx', sheet_name = '테이블')
# Out:
#      【0】 응답자 Profile Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                NaN        NaN    ▣ 사례수 ▣      비율(%)        NaN        NaN
# 1           ▣ 전  체 ▣        NaN     (1000)        100        NaN        NaN
# 2                 성별         남성      (500)         50        NaN        NaN
# 3                NaN         여성      (500)         50        NaN        NaN
# 4                 연령        20대      (240)         24        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 1959             NaN       경상북도       (53)   1.886792  20.754717  37.735849
# 1960             NaN       경상남도       (68)   1.470588  10.294118         50
# 1961             NaN        강원도       (20)          5         30         25
# 1962             NaN    세종특별자치시        (7)          0  14.285714  57.142857
# 1963             NaN    제주특별자치도       (10)          0         10         70
#
# ...

# %%
pd.read_excel('./data/롯데멤버스/005_ltmb_lime_table.xlsx', sheet_name = '테이블',
                   usecols='A:D',
                   index_col = 0,
                   skiprows=1,
                   )
# Out:
#          Unnamed: 1 ▣ 사례수 ▣     비율(%)
# ▣ 전  체 ▣        NaN  (1000)       100
# 성별               남성   (500)        50
# NaN              여성   (500)        50
# 연령              20대   (240)        24
# NaN             30대   (260)        26
# ...             ...     ...       ...
# NaN            경상북도    (53)  1.886792
# NaN            경상남도    (68)  1.470588
# NaN             강원도    (20)         5
# NaN         세종특별자치시     (7)         0
# NaN         제주특별자치도    (10)         0
#
# [1963 rows x 3 columns]
