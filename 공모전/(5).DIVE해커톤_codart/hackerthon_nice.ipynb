# %% [markdown]
# ---
# ### DIVE 해커톤 All data 정리

# %%
import warnings ;warnings.filterwarnings('ignore')
import sys ;sys.path.append("../../")
from  CommonFunc_03 import *

Analysis_title("Dive all data 파일 정리 ")
data_column_info(data_column_info_str="""
- Author : Forrest DPark
- Description :  
.   ◻︎ Topic  : 
.   ◻︎ Detail : 
.   ◻︎ Due   : 
.   ◻︎ Reward : 
.   ◻︎ Main Link : 
.   ◻︎ Basecode Link :
.   ◻︎ DataSet Info:

- Update : 
    2024.09.25.Wed . PM 03.34 data 정리 start
""")
DataPreprocessing.plotSetting("default")
# Out:
# ✻✻✻✻______🤑 Dive all data 파일 정리  🤑______✻✻✻✻
# - Author: Forrest DPark
# - Description:
# .   ◻︎ Topic:
# .   ◻︎ Detail:
# .   ◻︎ Due:
# .   ◻︎ Reward:
# .   ◻︎ Main Link:
# .   ◻︎ Basecode Link:
# .   ◻︎ DataSet Info:
#
# - Update:
#     2024.09.25.Wed . PM 03.34 data 정리 start
#   - ◎ matplot graph set complete

# %%
# data_file_numbering()
data_dict=data_watch_range(1,9,data_folder_path="./Data/NICE평가정보")
# Out:
# ✻✻✻✻______🙄 1-10 번 파일 데이터 보고 분석 🙄______✻✻✻✻
# Data File 불러오는 중..:  1%|          | 1/100 [elapsed: 00:01 remaining: 02:21]
#   - Detected encoding: EUC-KR
# Data File 불러오는 중..:  5%|▌         | 5/100 [elapsed: 00:02 remaining: 00:48]
#   - Detected encoding: EUC-KR
# Data File 불러오는 중..: 12%|█▏        | 12/100 [elapsed: 00:04 remaining: 00:25]
#   - Detected encoding: EUC-KR
# Data File 불러오는 중..: 22%|██▏       | 22/100 [elapsed: 00:05 remaining: 00:15]
#   - Detected encoding: EUC-KR
# Data File 불러오는 중..: 35%|███▌      | 35/100 [elapsed: 00:06 remaining: 00:09]
#   - Detected encoding: EUC-KR
# Data File 불러오는 중..: 51%|█████     | 51/100 [elapsed: 00:08 remaining: 00:05]
#   - Detected encoding: EUC-KR
# Data File 불러오는 중..: 70%|███████   | 70/100 [elapsed: 00:09 remaining: 00:02]
#   - Detected encoding: EUC-KR
# Data File 불러오는 중..: 92%|█████████▏| 92/100 [elapsed: 00:11 remaining: 00:00]
#   - Detected encoding: EUC-KR
#   - Detected encoding: None
# ...

# %%
nice01=DataPreprocessing.key_selector(data_dict,0,df_info_show=True)
nice02=DataPreprocessing.key_selector(data_dict,0,df_info_show=True)
nice03=DataPreprocessing.key_selector(data_dict,0,df_info_show=True)
nice04=DataPreprocessing.key_selector(data_dict,0,df_info_show=True)
nice5=DataPreprocessing.key_selector(data_dict,0,df_info_show=True)
nice61=DataPreprocessing.key_selector(data_dict,0,df_info_show=True)
nice01=DataPreprocessing.key_selector(data_dict,0,df_info_show=True)
# Out:
# ◎  1.BUSAN_DIVE_STAT_202209.csv----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# -Data info :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133 entries, 0 to 2132
# Columns: 107 entries, B_DATE to COUNT_AMT_FPAY_M3
# dtypes: float64(30), int64(76), object(1)
# memory usage: 1.7+ MB
# -DataFrame.head :
#    B_DATE META_ADD  GENDER  AGE  AVG_INCOME  MED_INCOME  AVG_INCOMEX  \
# 0  202209       전국       0    0        3775        3100         3147
# 1  202209       전국       0   10        2138        2100         2130
# 2  202209       전국       0   20        2749        2300         2547
#
#    IN_DIST_RO  IN_SH  IN_MAX  ...  SUM_CHECK_1   SUM_ABRO_1  AVG_CRED_1  \
# 0       411.4   10.1    3900  ...  15505891500  652041310.0        1887
# 1       233.0    5.6    2200  ...    453399990     182340.0         308
# ...

# %%
data_file_numbering(data_dir="./Data/롯데멤버스")
data_dict_lotte=data_watch_range(1,5,data_folder_path="./Data/롯데멤버스")
data_file_numbering(data_dir="./Data/삼성카드")
data_dict_samsung=data_watch_range(1,1,data_folder_path="./Data/삼성카드")
# Out:
# 4.BUSAN_DIVE_STAT_202306.csv
# 3.BUSAN_DIVE_STAT_202312.csv
# 5.BUSAN_DIVE_STAT_202303.csv
# 1.BUSAN_DIVE_STAT_202209.csv
# 8.BUSAN_DIVE_STAT_202203.csv
# 6.BUSAN_DIVE_STAT_202212.csv
# 2.BUSAN_DIVE_STAT_202309.csv
# 7.BUSAN_DIVE_STAT_202206.csv
# 9.부산테크노파크_DIVE2024_테이블레이아웃.xlsx
# 파일 1.003_ltmb_mart_data.csv 이 1.1.003_ltmb_mart_data.csv 으로 변경되었습니다.
# 파일 2.002_ltmb_k7_data.csv 이 2.2.002_ltmb_k7_data.csv 으로 변경되었습니다.
# 파일 4.006_ltmb_lime_data.xlsx 이 3.4.006_ltmb_lime_data.xlsx 으로 변경되었습니다.
# 파일 3.001_ltmb_layout.xlsx 이 4.3.001_ltmb_layout.xlsx 으로 변경되었습니다.
# 파일 5.005_ltmb_lime_table.xlsx 이 5.5.005_ltmb_lime_table.xlsx 으로 변경되었습니다.
# ✻✻✻✻______🙄 1-6 번 파일 데이터 보고 분석 🙄______✻✻✻✻
# Data File 불러오는 중..:  1%|          | 1/100 [elapsed: 00:00 remaining: 00:39]
#   - Detected encoding: None
#   - Detected encoding: UTF-8-SIG
# Data File 불러오는 중..: 12%|█▏        | 12/100 [elapsed: 00:05 remaining: 00:31]
#   - Detected encoding: None
#   - Detected encoding: None
# ...
