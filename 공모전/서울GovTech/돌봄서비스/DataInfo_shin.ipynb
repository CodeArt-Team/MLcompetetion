# %%
import pandas as pd

data1 = pd.read_excel('./데이터파일/여성가족부_아이돌봄 월별신청현황 정보 서비스_20240612.xlsx')
data2 = pd.read_excel('./데이터파일/여성가족부_아이돌봄 월별신청현황-시간대별 정보 서비스_20240612.xlsx')
data3 = pd.read_excel('./데이터파일/여성가족부_아이돌봄 월별신청현황-시간대별 정보 서비스_20240612.xlsx')
data4 = pd.read_excel('./데이터파일/여성가족부_아이돌봄 누적아동실적현황-서비스시간대별 정보 서비스_20240612.xlsx')
data5 = pd.read_excel('./데이터파일/여성가족부_아이돌보미 현황 정보 서비스_20240611.xlsx')

C0421 = data5[data5['아이돌봄기관번호'] == 'C0421']
C0421['기준연월'] = C0421['기준연월'].astype(str)
C0421['year'] = C0421['기준연월'].str[:4]
C0421
# Out:
# /var/folders/kx/k_4qtb_x3sdfhb0lmwqxqw_h0000gn/T/ipykernel_7683/2945587261.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   C0421['기준연월'] = C0421['기준연월'].astype(str)
# /var/folders/kx/k_4qtb_x3sdfhb0lmwqxqw_h0000gn/T/ipykernel_7683/2945587261.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   C0421['year'] = C0421['기준연월'].str[:4]
#          기준연월 아이돌봄기관번호     아이돌봄기관명 상위아이돌봄기관번호  상위아이돌봄기관명  당월돌보미수  당월종합형가능돌보미수  \
# ...
