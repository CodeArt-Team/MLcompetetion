# %% [markdown]
# ----
# ###
# 돌봄 서비스 데이터 보기
#
#  Author : DPark
#  Date : 2024.08.23
#  Description :  21-28 번 파일 데이터 보고 분석

# %%
import warnings ;warnings.filterwarnings('ignore')
import sys ;sys.path.append("../../../")
from  CommonFunc import *
DataPreprocessing.plotSetting(Title="21-28 번 파일 데이터 보고 분석 ")

## Data Fetching
data_folder_path="./데이터파일"
data_dict=DataPreprocessing.data_fetch(data_folder_path)

## Data Info
for i in sorted(data_dict.keys()):
    print(green(f"------------{i} 파일 데이터 INFORMATION-------------",True))
    DataPreprocessing.dataInfo(data_dict[i])
# Out:
# ◎ 현재 경로의 파일들 목록 --
#   0. 데이터파일
#   1. 사진
#   2. DataInfo_DGPark.ipynb
#   3. DataInfo_shin.ipynb
#   4. 데이터 읽어오기_jihwan.ipynb
#   5. 여가부_돌봄데이터.ipynb
# ◎ 주피터 가상환경 체크 : base
# ◎ Python 설치 경로:/opt/anaconda3/bin/python
# ◎ Graph 한글화 Setting
# ______👏👏 OS platform 한글 세팅완료
# ✻✻✻✻______🤑 21-28 번 파일 데이터 보고 분석  🤑______✻✻✻✻
# 100%|██████████| 36/36 [00:01<00:00, 28.61it/s]
#   21.여성가족부_아이돌봄서비스_연도별_정부지원시간설정_20240101.xlsx
#   22.여성가족부_아이돌봄서비스_전화모니터링결과_지표문항_3점 척도_20240331.xlsx
#   23.여성가족부_아이돌봄서비스_전화모니터링결과_지표문항_5점척도_20240331.xlsx
#   24.여성가족부_아이돌봄서비스_전화모니터링결과_지표문항별응답_3점 척도_20240331.xlsx
#   25.여성가족부_아이돌봄서비스_전화모니터링결과_지표문항별응답_5점 척도_20240331.xlsx
#   26.여성가족부_아이돌봄서비스제공기관_20231201.xlsx
#   27.여성가족부_아이돌봄신청처리단계_20230101.xlsx
#   28.여성가족부_아이돌봄정부지원 자격여부 입증서류 및 확인방법_20230101.xlsx
# ------------21.여성가족부_아이돌봄서비스_연도별_정부지원시간설정_20240101.xlsx 파일 데이터 INFORMATION-------------
# - column 수 : 3
# Index(['적용일자', '시간제년간지원시간', '종일제월간정부지원시간'], dtype='object')
# - row 수    : 8
# - null 수   : 0
# - 칼럼별 데이터 중복체크
# ...

# %% [markdown]
# ---
# ### Data Analysis
# ------------21.여성가족부_아이돌봄서비스_연도별_정부지원시간설정_20240101.xlsx 파일 데이터 INFORMATION-------------
#
#
#     ◎
#     ◎
#     ◎
#     ◎
#     ◎
#     ◎
#
# ------------21.여성가족부_아이돌봄서비스_연도별_정부지원시간설정_20240101.xlsx 파일 데이터 INFORMATION-------------
#
#
#     ◎
#     ◎
#     ◎
#     ◎
#     ◎
#     ◎
# ------------21.여성가족부_아이돌봄서비스_연도별_정부지원시간설정_20240101.xlsx 파일 데이터 INFORMATION-------------
#
#
#     ◎
#     ◎
#     ◎
#     ◎
#     ◎
#     ◎
#
# ------------21.여성가족부_아이돌봄서비스_연도별_정부지원시간설정_20240101.xlsx 파일 데이터 INFORMATION-------------
#
#
#     ◎
#     ◎
#     ◎
#     ◎
#     ◎
#     ◎
#
# ------------21.여성가족부_아이돌봄서비스_연도별_정부지원시간설정_20240101.xlsx 파일 데이터 INFORMATION-------------
#
#
#     ◎
#     ◎
#     ◎
#     ◎
#     ◎
#     ◎
#
#
#
#
# . ------------28.여성가족부_아이돌봄정부지원 자격여부 입증서류 및 확인방법_20230101.xlsx 파일 데이터 INFORMATION-------------
#
#     ◎  자격 여부 입증 서류 에 대한 데이터 이다.
#     ◎  2023 년도 데이터 만 있다.
#     ◎  가정의 구분 : 맞벌이가정, 기타 양육 부담 가정, 다문화 가정, 다자녀 가정, 한부모 가정, 장애부모 가정, 청소년 부모가정 이있다.
#     ◎  각가정마다 아이돌봄 정부지원 을 받기위해 제출해야하는 서류가 다 다르다.

# %%
### Data 순서 대로 까보기 
num = 1
data_num= sorted(data_dict.keys())[num]
print(data_num)
data_dict[data_num]
# Out:
# 22.여성가족부_아이돌봄서비스_전화모니터링결과_지표문항_3점 척도_20240331.xlsx
#            기준년월                            센터명 서비스종류   서비스유형       응답일자  \
# 0    2024-03-01                    충북 옥천군 가족센터   시간제  시간제-가형 2020-01-01
# 1    2024-03-01                    충북 옥천군 가족센터   시간제  시간제-나형 2020-01-01
# 2    2024-03-01                    충북 옥천군 가족센터   시간제  시간제-다형 2020-01-01
# 3    2024-03-01                    충북 옥천군 가족센터   시간제  시간제-라형 2020-01-01
# 4    2024-03-01                    충북 옥천군 가족센터   종일제  종일제-가형 2020-01-01
# ...         ...                            ...   ...     ...        ...
# 1819 2024-03-01  경기 시흥시 사회적협동조합 경기시흥작은자리지역자활센터   시간제  시간제-라형 2020-01-01
# 1820 2024-03-01  경기 시흥시 사회적협동조합 경기시흥작은자리지역자활센터   종일제  종일제-가형 2020-01-01
# 1821 2024-03-01  경기 시흥시 사회적협동조합 경기시흥작은자리지역자활센터   종일제  종일제-나형 2020-01-01
# 1822 2024-03-01  경기 시흥시 사회적협동조합 경기시흥작은자리지역자활센터   종일제  종일제-다형 2020-01-01
# 1823 2024-03-01  경기 시흥시 사회적협동조합 경기시흥작은자리지역자활센터   종일제  종일제-라형 2020-01-01
#
# ...

# %% [markdown]
# ------------22.여성가족부_아이돌봄서비스_전화모니터링결과_지표문항_3점 척도_20240331.xlsx 파일 데이터 INFORMATION-------------
#     ◎  전화모니터링결과
#     - 서비스의 종류는 시간제와 종일제가 있다.
#     - 서비스 유형은 시간제(가~라형), 종일제(가~라) 형이있다.
#     - 상위센터명은 돌보미서비스 관리 군집 장소인것같다.
#     - 3점 척도 1,2,3점 가구수 로 무언가를 평가하는것 같다.ㅏ
#
# ------------21.여성가족부_아이돌봄서비스_연도별_정부지원시간설정_20240101.xlsx 파일 데이터 INFORMATION-------------
#     ◎  연도별 정부지원시간 설정  : 아이돌범서비스를 지원하는 시간이 연도별로 정해져 있는 것같다.
#     ◎  17년 부터 24년 까지 있다. 시간은 480시간에서 960시간가지 올라왔다.
