# %% [markdown]
# ----
# ####
# 서울올림픽기념국민체육진흥공단_스포츠강좌이용권 등록강좌 정보
# <br><img src = "https://www.notion.so/image/https%3A%2F%2Fprod-files-secure.s3.us-west-2.amazonaws.com%2F914ff162-e9aa-4454-80d2-30b702551154%2F539ecae1-9b5e-417f-9b5f-32058ce2e70a%2Fimage.png?table=block&id=ff0f36dc-21c5-49e3-9f64-eca18d0ee5e7&spaceId=914ff162-e9aa-4454-80d2-30b702551154&width=1710&userId=d72aebc7-576c-4f0e-9c69-1d5d32da7874&cache=v2" width="700" height="400"/><br>
#
# End point
# http://apis.data.go.kr/B551014/SRVC_OD_API_FACIL_COURSE
#
# http://apis.data.go.kr/B551014/SRVC_OD_API_FACIL_COURSE/Servicekey=w1N+WdpiUt4yMy2JifOenamzNXc6HCceZ596C21rNM+LICP2KiUHN0E0F3Zf4Yu13zM8Myc/ZtIzgFBcywyxXQ==
#
# ---
# 서울올림픽기념국민체육진흥공단_전국체육시설 정보
#
# <br><img src = "https://www.notion.so/image/https%3A%2F%2Fprod-files-secure.s3.us-west-2.amazonaws.com%2F914ff162-e9aa-4454-80d2-30b702551154%2F33e6d758-1025-4819-a8e3-fd4e0d7d94a6%2Fimage.png?table=block&id=2d0ace9e-8e7d-4d7d-934c-4660210e74de&spaceId=914ff162-e9aa-4454-80d2-30b702551154&width=1710&userId=d72aebc7-576c-4f0e-9c69-1d5d32da7874&cache=v2" width="700" height="300"/><br>
#
#
# ❏ End point
# http://apis.data.go.kr/B551014/SRVC_API_SFMS_FACI
#
# ❏ Encoding_key
#
# w1N%2BWdpiUt4yMy2JifOenamzNXc6HCceZ596C21rNM%2BLICP2KiUHN0E0F3Zf4Yu13zM8Myc%2FZtIzgFBcywyxXQ%3D%3D
#
# ❏ Decoding_key
# w1N+WdpiUt4yMy2JifOenamzNXc6HCceZ596C21rNM+LICP2KiUHN0E0F3Zf4Yu13zM8Myc/ZtIzgFBcywyxXQ==

# %% [markdown]
# https://apis.data.go.kr/B551014/SRVC_OD_API_FACIL_COURSE/todz_api_facil_course_i?serviceKey=w1N%2BWdpiUt4yMy2JifOenamzNXc6HCceZ596C21rNM%2BLICP2KiUHN0E0F3Zf4Yu13zM8Myc%2FZtIzgFBcywyxXQ%3D%3D&pageNo=1&numOfRows=10&resultType=json

# %%
import warnings ;warnings.filterwarnings('ignore')
import sys ;sys.path.append("../../../")
from  CommonFunc import *
DataPreprocessing.plotSetting(Title="생활체육 데이터 훑어 보기 ")
#DataPreprocessing.dataInfo()
import sys
print(sys.executable)
import os
print(os.environ['CONDA_DEFAULT_ENV'])

# !conda env list
# !conda activate codeart_env 
# !conda env list
# Out:
# ______🔸🔸Graph 한글화 Setting
# ______👏👏 OS platform 한글 세팅완료
# ✻✻✻✻______🙄 생활체육 데이터 훑어 보기  🙄______✻✻✻✻
# /opt/anaconda3/bin/python
# base
# # conda environments:
# #
# base                  *  /opt/anaconda3
# codeart_env              /opt/anaconda3/envs/codeart_env
#
#
# CondaError: Run 'conda init' before 'conda activate'
#
# # conda environments:
# #
# base                  *  /opt/anaconda3
# codeart_env              /opt/anaconda3/envs/codeart_env

# %%
# !pip install ipykernel
# !python -m ipykernel install --user --name codeart_env --display-name "Python (codeart_env)"
# Out:
# ...
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Installed kernelspec codeart_env in /Users/forrestdpark/Library/Jupyter/kernels/codeart_env

# %%
imd("https://www.notion.so/image/https%3A%2F%2Fprod-files-secure.s3.us-west-2.amazonaws.com%2F914ff162-e9aa-4454-80d2-30b702551154%2F33e6d758-1025-4819-a8e3-fd4e0d7d94a6%2Fimage.png?table=block&id=2d0ace9e-8e7d-4d7d-934c-4660210e74de&spaceId=914ff162-e9aa-4454-80d2-30b702551154&width=1710&userId=d72aebc7-576c-4f0e-9c69-1d5d32da7874&cache=v2")
imd("https://www.notion.so/image/https%3A%2F%2Fprod-files-secure.s3.us-west-2.amazonaws.com%2F914ff162-e9aa-4454-80d2-30b702551154%2F539ecae1-9b5e-417f-9b5f-32058ce2e70a%2Fimage.png?table=block&id=ff0f36dc-21c5-49e3-9f64-eca18d0ee5e7&spaceId=914ff162-e9aa-4454-80d2-30b702551154&width=1710&userId=d72aebc7-576c-4f0e-9c69-1d5d32da7874&cache=v2")
# Out:
# <br><img src = "https://www.notion.so/image/https%3A%2F%2Fprod-files-secure.s3.us-west-2.amazonaws.com%2F914ff162-e9aa-4454-80d2-30b702551154%2F33e6d758-1025-4819-a8e3-fd4e0d7d94a6%2Fimage.png?table=block&id=2d0ace9e-8e7d-4d7d-934c-4660210e74de&spaceId=914ff162-e9aa-4454-80d2-30b702551154&width=1710&userId=d72aebc7-576c-4f0e-9c69-1d5d32da7874&cache=v2" width="700" height="300"/><br>
# <br><img src = "https://www.notion.so/image/https%3A%2F%2Fprod-files-secure.s3.us-west-2.amazonaws.com%2F914ff162-e9aa-4454-80d2-30b702551154%2F539ecae1-9b5e-417f-9b5f-32058ce2e70a%2Fimage.png?table=block&id=ff0f36dc-21c5-49e3-9f64-eca18d0ee5e7&spaceId=914ff162-e9aa-4454-80d2-30b702551154&width=1710&userId=d72aebc7-576c-4f0e-9c69-1d5d32da7874&cache=v2" width="700" height="300"/><br>

# %% [markdown]
# ---
# ###REST API json type 데이터 불러오기

# %%
api_address  ="https://apis.data.go.kr/B551014/SRVC_OD_API_FACIL_COURSE/todz_api_facil_course_i?serviceKey=w1N%2BWdpiUt4yMy2JifOenamzNXc6HCceZ596C21rNM%2BLICP2KiUHN0E0F3Zf4Yu13zM8Myc%2FZtIzgFBcywyxXQ%3D%3D&pageNo=1&numOfRows=10&resultType=json"


endpoint ="https://apis.data.go.kr/B551014/SRVC_OD_API_FACIL_COURSE/todz_api_facil_course_i?serviceKey="
encode_key ="w1N%2BWdpiUt4yMy2JifOenamzNXc6HCceZ596C21rNM%2BLICP2KiUHN0E0F3Zf4Yu13zM8Myc%2FZtIzgFBcywyxXQ%3D%3D"
decode_key ="w1N+WdpiUt4yMy2JifOenamzNXc6HCceZ596C21rNM+LICP2KiUHN0E0F3Zf4Yu13zM8Myc/ZtIzgFBcywyxXQ=="
option ="&pageNo=1&numOfRows=10&resultType=json"

api = endpoint+encode_key+option
#!pip install --upgrade requests urllib3

from urllib.parse import urlencode,unquote
import requests, json


queryString ="?"+urlencode(
    {
        "serviceKey":unquote(f"{encode_key}"),
        "pageNo":1,
        "numOfRows":1,
        "resultType":"json",
        
    }
)
endpoint_base ="https://apis.data.go.kr/B551014/SRVC_OD_API_FACIL_COURSE/todz_api_facil_course_i"
query_URL = endpoint_base+queryString


response = requests.get(endpoint_base,params=queryString)
print(response)
# data =json.load(r)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:652, in HTTPSConnection.connect(self)
#     650 server_hostname_rm_dot = server_hostname.rstrip(".")
# ...

# %% [markdown]
# ---
# ### url 은 되는데 파이썬 쪽에서 접근이 안됨.

# %%
# !pip install --upgrade pip
# !pip install --upgrade requests urllib3
# !pip show requests
# !pip show urllib3

# !pip install --upgrade certifi
# Out:
# Name: requests
# Version: 2.31.0
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache 2.0
# Location: /opt/anaconda3/lib/python3.11/site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, bertviz, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datasets, datashader, folium, googlemaps, huggingface-hub, intake, jupyterlab_server, panel, requests-file, requests-mock, requests-oauthlib, requests-toolbelt, spacy, Sphinx, streamlit, tensorflow, tldextract, transformers, tweepy, weasel, webdriver-manager
# Name: urllib3
# Version: 2.2.2
# Summary: HTTP library with thread-safe connection pooling, file post, and more.
# Home-page:
# Author:
# Author-email: Andrey Petrov <andrey.petrov@shazow.net>
# License:
# ...

# %%
# !pip install requests==2.31.0 clyent==1.2.1
# !pip install requests_mock
# !conda install requests=2.31.0 clyent=1.2.1 requests-mock
# !conda install -c conda-forge requests-mock clyent=1.2.1
# !pip install requests-mock clyent==1.2.1


## 새로운 가상환경에서 해보자 
# !conda create -n codeart_env python=3.11 -y
# !conda activate codeart_env

# 필요한 패키지 설치
# !conda install requests=2.31.0 clyent=1.2.1 requests-mock -y
# Out:
# ...
# Channels:
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/codeart_env
#
#   added / updated specs:
#     - python=3.11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h80987f9_6         129 KB
#     ca-certificates-2024.7.2   |       hca03da5_0         128 KB
#     libffi-3.4.4               |       hca03da5_1         120 KB
#     openssl-3.0.14             |       h80987f9_0         4.3 MB
#     pip-24.2                   |  py311hca03da5_0         2.8 MB
#     python-3.11.9              |       hb885b13_0        15.5 MB
#     setuptools-72.1.0          |  py311hca03da5_0         3.0 MB
#     sqlite-3.45.3              |       h80987f9_0         1.2 MB
#     tk-8.6.14                  |       h6ba3021_0         3.3 MB
# ...

# %%
print(query_URL)
from bs4 import BeautifulSoup
import urllib.request as req
import ssl
import urllib.request as req

context = ssl._create_unverified_context()
res = req.urlopen(query_URL, context=context)




print(res)

# res = req.urlopen(query_URL)
# Out:
# https://apis.data.go.kr/B551014/SRVC_OD_API_FACIL_COURSE/todz_api_facil_course_i?serviceKey=w1N%2BWdpiUt4yMy2JifOenamzNXc6HCceZ596C21rNM%2BLICP2KiUHN0E0F3Zf4Yu13zM8Myc%2FZtIzgFBcywyxXQ%3D%3D&pageNo=1&numOfRows=1&resultType=json
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /opt/anaconda3/lib/python3.11/http/client.py:1294, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1293 """Send a complete request to the server."""
# -> 1294 self._send_request(method, url, body, headers, encode_chunked)
#
# ...
