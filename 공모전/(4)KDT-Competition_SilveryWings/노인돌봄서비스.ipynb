# %%
import warnings ;warnings.filterwarnings('ignore')
import sys ;sys.path.append("../../../");sys.path.append("../../")

from  CommonFunc import *

Analysis_title("노인 돌봄 서비스 개선을 위한 수요 예측 데이터 분석 ")
data_column_info(data_column_info_str="""
- Description :  Smiles 정제 맟 모델 학습, 저장 
- Author : Forrest DPark
- Update : 
    ○ 2024.09.02 by pdg : 노인 관련 데이터 모두 수집 
        1. 노인 돌봄 서비스 개선을 위한 수요 예측 데이터 분석
            - 인천광역시_연령별 노인인구 현황 https://www.data.go.kr/data/15055018/fileData.do
            - 부산광역시 남구 독거노인 현황 https://www.data.go.kr/data/15009848/fileData.doef 
            - 국민건강보험공단 노인 의료급여수급권자 틀니 임플란트 급여 신청현황 https://www.data.go.kr/data/15112423/fileData.do
        2. AI hub
            - 치매 고위험군 웨어러블 라이프로그 https://aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=data&dataSetSn=226

        3. 신나라 출처
            - 재가노인+복지시설_20240902154657.csv
            


""")

DataPreprocessing.plotSetting()
# Out:
# ✻✻✻✻______😜 노인 돌봄 서비스 개선을 위한 수요 예측 데이터 분석  😜______✻✻✻✻
# - Description: Smiles 정제 맟 모델 학습, 저장
# - Author: Forrest DPark
# - Update:
# ○ 2024.09.02 by pdg: 노인 관련 데이터 모두 수집
#         1. 노인 돌봄 서비스 개선을 위한 수요 예측 데이터 분석
# - 인천광역시_연령별 노인인구 현황 https: //www.data.go.kr/data/15055018/fileData.do
# - 부산광역시 남구 독거노인 현황 https: //www.data.go.kr/data/15009848/fileData.doef
# - 국민건강보험공단 노인 의료급여수급권자 틀니 임플란트 급여 신청현황 https: //www.data.go.kr/data/15112423/fileData.do
#         2. AI hub
# - 치매 고위험군 웨어러블 라이프로그 https: //aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=data&dataSetSn=226
#
#         3. 신나라 출처
#             - 재가노인+복지시설_20240902154657.csv
#   - ◎ matplot graph set complete

# %%
# data2 = data_watch_one(1 , dataInfo=False)
# data3 = data_watch_one(2 , dataInfo=False)
# data4 = data_watch_one(3 , dataInfo=False)
data5 = data_watch_one(5 , dataInfo=False)
# Out:
# ✻✻✻✻______🙄 5-6 번 파일 데이터 보고 분석  🙄______✻✻✻✻
# Data File 불러오는 중..:  1%|          | 1/100 [elapsed: 00:00 remaining: 00:01]
#   - Detected encoding: UTF-8-SIG
# 5.재가노인+복지시설_20240902154657.csv 파일의 데이터 프레임.tail()
# 	0 번째 : 5.재가노인+복지시설_20240902154657.csv
# 	0번째 데이터 5.재가노인+복지시설_20240902154657.csv 호출합니다.
# <div style="text-align: center; margin-left: 50px;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>자치구별(1)</th>
#       <th>자치구별(2)</th>
#       <th>2022</th>
#       <th>2022.1</th>
#       <th>2022.2</th>
#       <th>2022.3</th>
#       <th>2022.4</th>
#       <th>2022.5</th>
#       <th>2022.6</th>
#       <th>2022.7</th>
#       <th>2022.8</th>
#       <th>2022.9</th>
#       <th>2022.10</th>
#       <th>2022.11</th>
#       <th>2022.12</th>
#       <th>2022.13</th>
#       <th>2022.14</th>
#       <th>2022.15</th>
#       <th>2022.16</th>
#       <th>2022.17</th>
#       <th>2022.18</th>
#       <th>2022.19</th>
# ...

# %%
data6 = data_watch_one(6 , dataInfo=False)
# Out:
# ✻✻✻✻______😜 6-7 번 파일 데이터 보고 분석  😜______✻✻✻✻
# Data File 불러오는 중..:  1%|          | 1/100 [elapsed: 00:00 remaining: 00:00]
#   - Detected encoding: UTF-8-SIG
# 6.독거노인+현황(성별_동별)_20240902155508.csv 파일의 데이터 프레임.tail()
# 	0 번째 : 6.독거노인+현황(성별_동별)_20240902155508.csv
# 	0번째 데이터 6.독거노인+현황(성별_동별)_20240902155508.csv 호출합니다.
# <div style="text-align: center; margin-left: 50px;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>동별(1)</th>
#       <th>동별(2)</th>
#       <th>동별(3)</th>
#       <th>2023</th>
#       <th>2023.1</th>
#       <th>2023.2</th>
#       <th>2023.3</th>
#       <th>2023.4</th>
#       <th>2023.5</th>
#       <th>2023.6</th>
#       <th>2023.7</th>
#       <th>2023.8</th>
#       <th>2023.9</th>
#       <th>2023.10</th>
#       <th>2023.11</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>451</th>
#       <td>서울특별시</td>
#       <td>강동구</td>
#       <td>천호2동</td>
#       <td>1912</td>
# ...

# %%
dataNum = 5
data_test = data_watch_one(dataNum , dataInfo=False)
test = DataPreprocessing.key_selector(data_test,0)
# Out:
# ✻✻✻✻______😜 5-6 번 파일 데이터 보고 분석  😜______✻✻✻✻
# Data File 불러오는 중..:  1%|          | 1/100 [elapsed: 00:00 remaining: 00:00]
#   - Detected encoding: UTF-8-SIG
# 5.재가노인+복지시설_20240902154657.csv 파일의 데이터 프레임.tail()
# 	0 번째 : 5.재가노인+복지시설_20240902154657.csv
# 	0번째 데이터 5.재가노인+복지시설_20240902154657.csv 호출합니다.
# <div style="text-align: center; margin-left: 50px;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>자치구별(1)</th>
#       <th>자치구별(2)</th>
#       <th>2022</th>
#       <th>2022.1</th>
#       <th>2022.2</th>
#       <th>2022.3</th>
#       <th>2022.4</th>
#       <th>2022.5</th>
#       <th>2022.6</th>
#       <th>2022.7</th>
#       <th>2022.8</th>
#       <th>2022.9</th>
#       <th>2022.10</th>
#       <th>2022.11</th>
#       <th>2022.12</th>
#       <th>2022.13</th>
#       <th>2022.14</th>
#       <th>2022.15</th>
#       <th>2022.16</th>
#       <th>2022.17</th>
#       <th>2022.18</th>
#       <th>2022.19</th>
# ...

# %%
test.columns
test
# Out:
#     자치구별(1)  자치구별(2)      2022       2022.1       2022.2    2022.3    2022.4  \
# 0   자치구별(1)  자치구별(2)        합계           합계           합계        합계   방문요양서비스
# 1   자치구별(1)  자치구별(2)  시설수 (개소)  이용인원-정원 (명)  이용인원-현원 (명)  종사자수 (명)  시설수 (개소)
# 2        합계       소계      1878        14629        39483     33582       767
# 3        합계      종로구        20          102          428       260         7
# 4        합계       중구        26          203          679       360        10
# 5        합계      용산구        21          139          395       181         8
# 6        합계      성동구        43          360          625       476        17
# 7        합계      광진구        45          508          856       484        17
# 8        합계     동대문구        82          892         1417       742        29
# 9        합계      중랑구       155          960         2643      2132        61
# 10       합계      성북구        78          747         1295       911        30
# ...
